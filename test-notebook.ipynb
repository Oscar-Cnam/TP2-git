# %%
stock = {
"pains au chocolat": 500,
"croissants": 400,
"baguettes": 500,
"beignets": 200
}

# %%
print(stock)
# Out:
# {'pains au chocolat': 500, 'croissants': 400, 'baguettes': 500, 'beignets': 200}
